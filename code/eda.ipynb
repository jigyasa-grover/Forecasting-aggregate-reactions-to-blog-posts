# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
headers = [l.strip() for l in open("headers")]

# %%
df = pd.read_csv("../dataset/blogData_train.csv", header=None, names=headers, index_col=False)

# %%
def get_avg_day(column):
    return df['target_number_of_comments_in_next_24_hours'][df[column] == 1].values

# %%
publication = {
    "Mon": get_avg_day('publication_weekday:monday'),
    "Tue": get_avg_day('publication_weekday:tuesday'),
    "Wed": get_avg_day('publication_weekday:wednesday'),
    "Thu": get_avg_day('publication_weekday:thursday'),
    "Fri": get_avg_day('publication_weekday:friday'),
    "Sat": get_avg_day('publication_weekday:saturday'),
    "Sun": get_avg_day('publication_weekday:sunday')
}

# %%
days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]

# %%
val = list()
for x in basetime:
    for l in basetime[x]:
        val.append((x, l))

# %%
new = pd.DataFrame(val, columns=['day', 'val'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x='day', y='val', data=new, capsize=0.1)
plt.title("Basetime Day vs. Target no. of comments")
# Out:
# Text(0.5,1,'Basetime Day vs. Target no. of comments')

# %%
df.target_number_of_comments_in_next_24_hours.describe()
# Out:
# count    52397.000000
# mean         6.764719
# std         37.706565
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max       1424.000000
# Name: target_number_of_comments_in_next_24_hours, dtype: float64

# %%
basetime = {
    "Mon": get_avg_day('basetime_weekday:monday'),
    "Tue": get_avg_day('basetime_weekday:tuesday'),
    "Wed": get_avg_day('basetime_weekday:wednesday'),
    "Thu": get_avg_day('basetime_weekday:thursday'),
    "Fri": get_avg_day('basetime_weekday:friday'),
    "Sat": get_avg_day('basetime_weekday:saturday'),
    "Sun": get_avg_day('basetime_weekday:sunday')
}

# %%
plt.bar(basetime.keys(), basetime.values())
plt.show()

# %%
df_new = df[df['target_number_of_comments_in_next_24_hours'] > 200]
df_new.target_number_of_comments_in_next_24_hours.plot.hist(bins=50)
plt.xlabel("# of comments > 200")
# Out:
# Text(0.5,0,'# of comments > 200')

# %%
df.target_number_of_comments_in_next_24_hours.plot.hist(bins=50)
plt.xlabel("# of comments")
# Out:
# Text(0.5,0,'# of comments')

# %%
df.target_number_of_comments_in_next_24_hours.plot.hist()

# %%
sns.set(color_codes=True)
sns.regplot(x='number_of_parent_pages', y='target_number_of_comments_in_next_24_hours', data=df)

# %%
sns.regplot(x='average_number_of_comments_parents_received', y='target_number_of_comments_in_next_24_hours', data=df)

# %%
sns.regplot(x='minimum_number_of_comments_parents_received', y='target_number_of_comments_in_next_24_hours', data=df)

# %%
sns.regplot(x='maximum_number_of_comments_parents_received', y='target_number_of_comments_in_next_24_hours', data=df)
